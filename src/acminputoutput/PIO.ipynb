# %% [markdown]
# 牛客ACM输入输出练习 https://www.nowcoder.com/exam/oj?page=1&tab=%E7%AE%97%E6%B3%95%E7%AC%94%E9%9D%A2%E8%AF%95%E7%AF%87&topicId=372

# %%
"""
PIO3
"""
import sys

for line in sys.stdin:
    a, b= map(int, line.strip().split())
    print(a + b)
"""
PIO3
"""
import sys

lines = [line.strip() for line in sys.stdin.readlines() if line.strip()]
n = len(lines)
for line in lines:
    a, b = map(int, line.split())
    print(a + b)

# %%
"""
PIO5
"""
import sys

lines = [line.strip() for line in sys.stdin.readlines() if line.strip()]
for line in lines:
    a, b = map(int, line.split())
    if a == 0 and b == 0:
        break
    print(a + b)

# %%
"""
PIO6
3
1 4 7
"""
import sys

n = int(sys.stdin.readline().strip())
nums = map(int, sys.stdin.readline().strip().split())
print(sum(nums))

# %%
"""
PIO7
"""
import sys

t = int(sys.stdin.readline().strip())
for _ in range(t):
    n = int(sys.stdin.readline().strip())
    nums = map(int, sys.stdin.readline().strip().split())
    print(sum(nums))

# %%
"""
PIO7
"""
import sys

lines = [line.strip() for line in sys.stdin.readlines() if line.strip()]
ptr = 0
t = int(lines[ptr])
ptr += 1
for _ in range(t):
    n = int(lines[ptr])
    ptr += 1
    nums = map(int, lines[ptr].split())
    ptr += 1
    print(sum(nums))

# %%
"""
PI8
"""
import sys

lines = [line.strip() for line in sys.stdin.readlines() if line.strip()]
ptr = 0
n, m = map(int, lines[ptr].split())
ptr += 1
ans = 0
for _ in range(n):
    nums = map(int, lines[ptr].split())
    ptr += 1
    ans += sum(nums)
print(ans)

# %%
"""
PIO10
"""
import sys

n = int(sys.stdin.readline().strip())
s = str(sys.stdin.readline().strip())
print(s[::-1])
"""
PIO10
"""
import sys

n = int(sys.stdin.readline().strip())
s = str(sys.stdin.readline().strip())
s_rev = ''.join(reversed(s))
print(s_rev)

# %%
"""
PIO12
"""
import sys

n, m = map(int, sys.stdin.readline().strip().split())
grid = [line.strip() for line in sys.stdin.readlines() if line.strip()]
for s in reversed(grid):
    print(s[::-1])

# %%
"""
PIO13
"""
import sys

t = int(sys.stdin.readline().strip())
for _ in range(t):
    n = int(sys.stdin.readline().strip())
    s = str(sys.stdin.readline().strip())
    # print(''.join(s.split())[::-1]) # 切片，拼接再反转
    print(s.replace(' ', '')[::-1]) # replace更快

# %%
"""
PIO14
"""
import sys

n = float(sys.stdin.readline().strip())
# print("{0:.3f}".format(n))
print(f"{n:.3f}")

# %%
"""
PIO14
"""
import sys

n = int(sys.stdin.readline().strip())
print(f"{n:09d}")

# %%
"""
PIO17
"""
import sys
import math

r = float(sys.stdin.readline().strip())
ans = math.pi * (r ** 2)
print(f"{ans:.3f}")

# %%
"""
PIO18
"""
import sys

n, m = map(int, sys.stdin.readline().strip().split())
ans = [1] * n
ans[-1] = m - n + 1
# for x in ans:
#     print(x, end=" ")
# print(*ans)
print(" ".join(map(str, ans)))
